# %%
import pandas as pd

# %%
import numpy as np

# %%
# Q.1  How can you check the dimensions (number of rows and columns) of a DataFrame?

# %%
data = {"Name" : ['Vivek', 'Ziyaan', 'Aman'],
        "Id no." : [1,2,3],
        "Batch" : ['a','b','c']}
df = pd.DataFrame(data)

dimension = df.shape

# %%
dimension
# Out:
# (3, 3)

# %%
#Q.2  Explain the difference between loc[] and iloc[] methods in pandas for indexing.

# %%
df
# Out:
#      Name  Id no. Batch
# 0   Vivek       1     a
# 1  Ziyaan       2     b
# 2    Aman       3     c

# %%
loc = df.loc[1,'Name']

# %%
loc
# Out:
# 'Ziyaan'

# %%
iloc = df.iloc[2,1]

# %%
iloc
# Out:
# 3

# %%
#Q.3  How can you read a Microsoft Excel file into a DataFrame using pandas?

# %%
df = pd.read_csv('Salaries.csv')
# Out:
# C:\Users\ratho\AppData\Local\Temp\ipykernel_17064\926554038.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Salaries.csv')

# %%
# Q.4 Explain the purpose of the to_csv() method in pandas and how it is used.

# %%
data = {"Name" : ['Vivek', 'Ziyaan', 'Aman'],
        "Id no." : [1,2,31],
        "Batch" : ['a','b','c']}
df = pd.DataFrame(data)

path = 'exam.txt'

df.to_csv(path)

# %%
#Q.5 How can you read data from a SQL database into a pandas DataFrame?

# %%
BC = pd.read_csv('Salaries.csv')
# Out:
# C:\Users\ratho\AppData\Local\Temp\ipykernel_8396\390843185.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   BC = pd.read_csv('Salaries.csv')

# %%
BC
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
#Q.6 Describe the process of selecting a single column in a DataFrame.

# %%
d = df.iloc[:,1]

# %%
d
# Out:
# 0     1
# 1     2
# 2    31
# Name: Id no., dtype: int64

# %%
selected_data_columns = df.loc[1]

# %%
selected_data_columns
# Out:
# Name      Ziyaan
# Id no.         2
# Batch          b
# Name: 1, dtype: object

# %%
#Q.7  Explain how to create a new column in a DataFrame based on calculations from existing columns.

# %%
data = {"Name" : ['Vivek', 'Ziyaan', 'Aman'],
        "Id no." : [1,2,31],
        "Batch" : ['a','b','c']}
df = pd.DataFrame(data)

# %%
df['Annual Income'] = df['Id no.']*5

# %%
df
# Out:
#      Name  Id no. Batch  Annual Income
# 0   Vivek       1     a              5
# 1  Ziyaan       2     b             10
# 2    Aman      31     c            155

# %%
#Q.8 What methods does pandas provide for detecting and handling missing values in a DataFrame?

# %%
data = {'A': [1, 2, np.nan, 4, np.nan],
        'B': [10, np.nan, np.nan, 40, 50],
        'C': [100, 200, 300, np.nan, np.nan]}
df = pd.DataFrame(data)

# %%
df
# Out:
#      A     B      C
# 0  1.0  10.0  100.0
# 1  2.0   NaN  200.0
# 2  NaN   NaN  300.0
# 3  4.0  40.0    NaN
# 4  NaN  50.0    NaN

# %%
df.isnull()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False
# 3  False  False   True
# 4   True  False   True

# %%
df.notnull()
# Out:
#        A      B      C
# 0   True   True   True
# 1   True  False   True
# 2  False  False   True
# 3   True   True  False
# 4  False   True  False

# %%
#Q.8 How can you drop rows with missing values from a DataFrame using pandas?

# %%
data = {'A': [1, 2, np.nan, 4, np.nan],
        'B': [10, np.nan, np.nan, 40, 50],
        'C': [100, 200, 300, np.nan, np.nan]}
df = pd.DataFrame(data)
df
# Out:
#      A     B      C
# 0  1.0  10.0  100.0
# 1  2.0   NaN  200.0
# 2  NaN   NaN  300.0
# 3  4.0  40.0    NaN
# 4  NaN  50.0    NaN

# %%
df.dropna(thresh = 2)
# Out:
#      A     B      C
# 0  1.0  10.0  100.0
# 1  2.0   NaN  200.0
# 3  4.0  40.0    NaN

# %%
#Q.9 Discuss techniques for filling missing values in a DataFrame using pandas.

# %%
data = {'A': [1, 2, np.nan, 4, np.nan],
        'B': [10, np.nan, np.nan, 40, 50],
        'C': [100, 200, 300, np.nan, np.nan]}
df = pd.DataFrame(data)
df
# Out:
#      A     B      C
# 0  1.0  10.0  100.0
# 1  2.0   NaN  200.0
# 2  NaN   NaN  300.0
# 3  4.0  40.0    NaN
# 4  NaN  50.0    NaN

# %%
df.ffill()
# Out:
#      A     B      C
# 0  1.0  10.0  100.0
# 1  2.0  10.0  200.0
# 2  2.0  10.0  300.0
# 3  4.0  40.0  300.0
# 4  4.0  50.0  300.0

# %%
df.bfill()
# Out:
#      A     B      C
# 0  1.0  10.0  100.0
# 1  2.0  40.0  200.0
# 2  4.0  40.0  300.0
# 3  4.0  40.0    NaN
# 4  NaN  50.0    NaN

# %%
Q.10 How can you calculate the mean, median, and standard deviation of a numerical column in a DataFrame?
# Out:
# Object `DataFrame` not found.

# %%
# MEAN

# %%
BC
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 BC
#
# NameError: name 'BC' is not defined

# %%
forMean = BC['TotalPay'].mean()
forMean
# Out:
# 74768.32197169267

# %%
forMedian = BC['TotalPay'].median()
forMedian
# Out:
# 71426.60999999999

# %%
ForSD =  BC['TotalPay'].std()
ForSD
# Out:
# 50517.005273949944

# %%
#Q.11  Explain how to use the groupby() function in pandas to group data for aggregation.

# %%
GroupBy = BC.groupby('BasePay')
GroupBy

# %%
mean = GroupBy.sum()
mean
# Out:
#                   Id                                      EmployeeName  \
# BasePay
# -166.01        72833                                    Irwin Sidharta
# -121.63        72866                                      Robert Scott
# -109.22        72873                                   Chung Huey Kung
# -106.6         72875                                         Jordan Li
# -101.88        72879                                   Richard Jackson
# ...              ...                                               ...
# 9991.53       142974                                    Thomas Mattias
# 9997.15       143970                                      James H Neal
# 9998.60       142583                                Jessica A Affolter
# 9999.59       144091                              Margaret S Hutchison
# Not Provided  594603  Not providedNot providedNot providedNot provided
#
#                                                       JobTitle  \
# BasePay
# ...

# %%
BC
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
BC.ffill()
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
BC.bfill()
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
BC = BC.replace("Not provided",np.NAN)
BC
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651                NaN
# 148651  148652                NaN
# 148652  148653                NaN
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
BC = BC.replace("Not Provided",np.NAN)

# %%
BC
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651                NaN
# 148651  148652                NaN
# 148652  148653                NaN
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0    56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6      9737.0
# ...                                                ...        ...         ...
# ...

# %%
BC.ffill()
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651      Roy I Tillery
# 148651  148652      Roy I Tillery
# 148652  148653      Roy I Tillery
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0    56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6      9737.0
# ...                                                ...        ...         ...
# ...

# %%
mean = df.groupby('JobTitle')
mean
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 mean = df.groupby('JobTitle')
#       2 mean
#
# File D:\anaconda 1\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# ...

# %%
#Q.12  Discuss the purpose of the value_counts() method in pandas and how it can be used.

# %%
ValueCount = BC['JobTitle'].value_counts().head()
ValueCount
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %%
#Q.13 How can you rename columns in a DataFrame using pandas?

# %%
BC.rename(columns= {'EmployeeName':'Vivek Rathod'},inplace=False)
# Out:
#             Id       Vivek Rathod  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651                NaN
# 148651  148652                NaN
# 148652  148653                NaN
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0    56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6      9737.0
# ...                                                ...        ...         ...
# ...

# %%
#Q.14 Describe methods for sorting data in a DataFrame based on column values.

# %%
a = BC.sort_values('OtherPay')
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 a = BC.sort_values('OtherPay')
#       2 a
#
# File D:\anaconda 1\Lib\site-packages\pandas\core\frame.py:6769, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6766     if isinstance(ascending, (tuple, list)):
#    6767         ascending = ascending[0]
# -> 6769     indexer = nargsort(
#    6770         k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    6771     )
#    6772 else:
#    6773     if inplace:
#
# File D:\anaconda 1\Lib\site-packages\pandas\core\sorting.py:429, in nargsort(items, kind, ascending, na_position, key, mask)
#     427     non_nans = non_nans[::-1]
#     428     non_nan_idx = non_nan_idx[::-1]
# --> 429 indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     430 if not ascending:
# ...

# %%
BC['OtherPay'] = pd.to_numeric(BC['OtherPay'])
a = BC.sort_values(by =['OtherPay'],ascending = True,inplace = False)
a
# Out:
#             Id      EmployeeName  \
# 84969    84970         Pei  Meng
# 148653  148654         Joe Lopez
# 107184  107185  Amelie E Bullard
# 96168    96169  John G Alexander
# 93200    93201      Jose A Lemus
# ...        ...               ...
# 0            1    NATHANIEL FORD
# 148646  148647               NaN
# 148650  148651               NaN
# 148651  148652               NaN
# 148652  148653               NaN
#
#                                               JobTitle    BasePay OvertimePay  \
# 84969                    IS Business Analyst-Principal  101274.51         0.0
# 148653                      Counselor, Log Cabin Ranch       0.00        0.00
# 107184                                   Special Nurse     6932.5         0.0
# 96168                                         Gardener   59733.32       46.76
# 93200                             Custodial Supervisor    66744.0      2234.4
# ...                                                ...        ...         ...
# ...

# %%
BC
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651                NaN
# 148651  148652                NaN
# 148652  148653                NaN
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0    56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6      9737.0
# ...                                                ...        ...         ...
# ...

# %%
Q.15 Explain how to remove duplicate rows from a DataFrame using pandas.

# %%
data = {'A': [1, 2, 1, 3, 2],
        'B': ['X', 'Y', 'X', 'Z', 'Y'],
        'C': [10, 20, 10, 30, 20]}

df = pd.DataFrame(data)

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#    A  B   C
# 0  1  X  10
# 1  2  Y  20
# 3  3  Z  30

# %%
BC
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...
